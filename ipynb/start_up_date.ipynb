# %%
import pandas as pd
import pyodbc

# Getting all startupdate from vw_Dim_Equipment_IncStatupDate
sql_query = """
	SELECT
		[EQUI_STRNO_FunctionalLocation]
		,[EQUI_EQUNR_Equipment]
		,[EQUI_EQKTX_EquipmentDescr]
		,[EQUI_EQART_TechnicalObjectType]
		,[EQUI_EARTX_TechnicalObjectTypeDescr]
		,[EQUI_STRNO_FunctionalLocation]
		,[EQUI_ATWRT_OverhaulDate]
		,[EQUI_INBDT_StartupDate]
	FROM [myANALYTICS_SP].[workarea.silver.dimension.enterprise.asset].[vw_Dim_Equipment_IncStatupDate]
	WHERE
		[EQUI_INBDT_StartupDate] <> 0
		AND [EQUI_BUKRS_CompanyCode] = '5000'
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df_start_up_date1 = pd.read_sql_query(sql_query, conn)

# file_path = 'csv/average_cost_per_maint_activity_all.csv'
# df_avg_cost_per_maint_activity.to_csv(file_path, index=True)

# Display the DataFrame
df_start_up_date1
# Out:
# C:\Users\r893859\AppData\Local\Temp\ipykernel_15760\1788882835.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_start_up_date1 = pd.read_sql_query(sql_query, conn)
#       EQUI_STRNO_FunctionalLocation EQUI_EQUNR_Equipment  \
# 0                          LX001814             60013347
# 1                          LX001814             60012710
# 2                          LX001814             60012095
# 3                          LX001814             60011654
# 4                          LX001814             60011029
# ...                             ...                  ...
# 15087                          None             10199990
# 15088                          None             10152953
# 15089                          None             50004080
# 15090                          None             10155158
# 15091                          None             10152995
#
#                       EQUI_EQKTX_EquipmentDescr  \
# 0              LX_CONTROLS LX001814 AT 61.208KM
# 1         LX_OTHER_DETAILS LX001814 AT 61.208KM
# 2               LX_VOLUMES LX001814 AT 61.208KM
# 3            LX_VISIBILITY LX001814 AT 61.208KM
# 4           LX_PED_DETAILS LX001814 AT 61.208KM
# ...                                         ...
# 15087         KBC137 - Combination Tool (Stihl)
# 15088   UEG001 - MOBILE LIGHTING PLANT (935QMT)
# 15089  440MDG - R/R Toyota Landcruiser (RRV812)
# 15090   KEL020 - WHEEL LOADER (JCB) Rego:C53428
# 15091           UWP001 - WATER PRESSURE CLEANER
#
#       EQUI_EQART_TechnicalObjectType EQUI_EARTX_TechnicalObjectTypeDescr  \
# 0                              30040                         LX_CONTROLS
# 1                              30095                    LX_OTHER_DETAILS
# 2                              30090                          LX_VOLUMES
# 3                              30080                       LX_VISIBILITY
# 4                              30070                      LX_PED_DETAILS
# ...                              ...                                 ...
# 15087                        PLTBCUT                 Plant: Brush Cutter
# 15088                        PLTGNRT                    Plant: Generator
# 15089                          L/COM                    Light Commercial
# 15090                        EMQELDR                E/Moving: End Loader
# 15091                        WATRPMP                  Water Pumping Unit
#
#       EQUI_STRNO_FunctionalLocation EQUI_ATWRT_OverhaulDate  \
# 0                          LX001814                    None
# 1                          LX001814                    None
# 2                          LX001814                    None
# 3                          LX001814                    None
# 4                          LX001814                    None
# ...                             ...                     ...
# 15087                          None                    None
# 15088                          None                    None
# 15089                          None                    None
# 15090                          None                    None
# 15091                          None                    None
#
#       EQUI_INBDT_StartupDate
# 0                   20150101
# 1                   20150101
# 2                   20150101
# 3                   20150101
# 4                   20150101
# ...                      ...
# 15087               20120210
# 15088               20060614
# 15089               20110501
# 15090               20070530
# 15091               20060811
#
# [15092 rows x 8 columns]

# %%
df_start_up_date1.isna().sum()
# Out:
# EQUI_STRNO_FunctionalLocation              9
# EQUI_EQUNR_Equipment                       0
# EQUI_EQKTX_EquipmentDescr                  0
# EQUI_EQART_TechnicalObjectType             0
# EQUI_EARTX_TechnicalObjectTypeDescr        0
# EQUI_STRNO_FunctionalLocation              9
# EQUI_ATWRT_OverhaulDate                15092
# EQUI_INBDT_StartupDate                     0
# dtype: int64

# %%
# Getting all startupdate from vw_Dim_FunctionalLocationStartupDate
sql_query = """
    SELECT
        [FLOC_STRNO_FunctionalLocation]
        ,[FLOC_PLTXT_FunctionalLocationDescr]
        ,[FLOC_EQART_TechnicalObjectType]
        ,[FLOC_EARTX_TechnicalObjectTypeDescr]
        ,[FLOC_STRNO_SuperiorFunctionalLocation]
        ,[FLOC_STORT_Location]
        ,[FLOC_STORT_LocationDescr]
        ,[IFLOT_DATAB_StartupDate]
    FROM [myANALYTICS_SP].[workarea.silver.dimension.enterprise.asset].[vw_Dim_FunctionalLocationStartupDate]
    WHERE
        IFLOT_DATAB_StartupDate <> 0
        AND [FLOC_BUKRS_CompanyCode] = '5000'
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df_start_up_date2 = pd.read_sql_query(sql_query, conn)

# file_path = 'csv/average_cost_per_maint_activity_all.csv'
# df_avg_cost_per_maint_activity.to_csv(file_path, index=True)

# Display the DataFrame
df_start_up_date2
# Out:
# C:\Users\r893859\AppData\Local\Temp\ipykernel_15760\3049478296.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_start_up_date2 = pd.read_sql_query(sql_query, conn)
#       FLOC_STRNO_FunctionalLocation FLOC_PLTXT_FunctionalLocationDescr  \
# 0                       ST001350-01           BALOOK-WANDOO ATS  - AT1
# 1                       ST001360-15                  BGE-AT0 ECO Phone
# 2                       ST001360-01              BLACKRIDGE ATS  - AT1
# 3                       ST001360-11                    BGE-AT0-YBAT-01
# 4                       ST001360-17                  BGE-AT0-DDW225-01
# ...                             ...                                ...
# 25837                      SQ030863           851/6 Motorised Isolator
# 25838                      SQ030862           851/5 Motorised Isolator
# 25839                      SQ030861           842/3 Motorised Isolator
# 25840                      SQ030860           841/2 Motorised Isolator
# 25841                      SQ030859           831/2 Motorised Isolator
#
#       FLOC_EQART_TechnicalObjectType FLOC_EARTX_TechnicalObjectTypeDescr  \
# 0                              70110                         Transformer
# 1                              PHONE                               Phone
# 2                              70110                         Transformer
# 3                            BATTERY                             Battery
# 4                              60400                 Network Transciever
# ...                              ...                                 ...
# 25837                          70120                           Isolators
# 25838                          70120                           Isolators
# 25839                          70120                           Isolators
# 25840                          70120                           Isolators
# 25841                          70120                           Isolators
#
#       FLOC_STRNO_SuperiorFunctionalLocation FLOC_STORT_Location  \
# 0                                  ST001350              BA0029
# 1                                  ST001360              BL0047
# 2                                  ST001360              BL0047
# 3                                  ST001360              BL0047
# 4                                  ST001360              BL0047
# ...                                     ...                 ...
# 25837                                  None              BL0056
# 25838                                  None              BL0056
# 25839                                  None              DU0136
# 25840                                  None              DU0136
# 25841                                  None              ED0151
#
#       FLOC_STORT_LocationDescr IFLOT_DATAB_StartupDate
# 0                Balook-Wandoo                20180523
# 1                   Blackridge                19860101
# 2                   Blackridge                20200521
# 3                   Blackridge                20141130
# 4                   Blackridge                20170131
# ...                        ...                     ...
# 25837                    Bluff                20190901
# 25838                    Bluff                20190901
# 25839                 Duaringa                20190901
# 25840                 Duaringa                20190901
# 25841                Edungalba                20190901
#
# [25842 rows x 8 columns]

# %%
df_start_up_date2.isna().sum()
# Out:
# FLOC_STRNO_FunctionalLocation              0
# FLOC_PLTXT_FunctionalLocationDescr         0
# FLOC_EQART_TechnicalObjectType             0
# FLOC_EARTX_TechnicalObjectTypeDescr      105
# FLOC_STRNO_SuperiorFunctionalLocation     46
# FLOC_STORT_Location                        0
# FLOC_STORT_LocationDescr                 536
# IFLOT_DATAB_StartupDate                    0
# dtype: int64

# %%
# Getting all FLOC from [vw_Dim_FunctionalLocation] where CompanyCode = 5000
sql_query = """
    SELECT
        FLOC_TPLNR_FunctionalLocationInternalKey,
        FLOC_STRNO_FunctionalLocation,
        FLOC_PLTXT_FunctionalLocationDescr,
        FLOC_TYPTX_FunctionalLocationCategoryDescr,
        FLOC_EQART_TechnicalObjectType,
        FLOC_EARTX_TechnicalObjectTypeDescr,
        FLOC_BUKRS_CompanyCode,
        FLOC_STORT_Location,
        FLOC_STORT_LocationDescr
    FROM [myANALYTICS_SP].[silver.dimension.enterprise.asset].[vw_Dim_FunctionalLocation]
	WHERE FLOC_BUKRS_CompanyCode = '5000'
	ORDER BY FLOC_STRNO_FunctionalLocation
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df_all_floc = pd.read_sql_query(sql_query, conn)

# Display the DataFrame
df_all_floc
# Out:
# C:\Users\r893859\AppData\Local\Temp\ipykernel_15760\859435568.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_all_floc = pd.read_sql_query(sql_query, conn)
#        FLOC_TPLNR_FunctionalLocationInternalKey FLOC_STRNO_FunctionalLocation  \
# 0                          ?0100000000000387769                       AC-01CH
# 1                          ?0100000000000365741                       AC-01JN
# 2                          ?0100000000000366347                  AC-01JN-JNJN
# 3                          ?0100000000000377748                       AC-01NA
# 4                          ?0100000000000387811                       AC-01PA
# ...                                         ...                           ...
# 174139                     ?0100000000000253349                      WL000203
# 174140                     ?0100000000000253351                      WL000204
# 174141                     ?0100000000000253372                      WL000205
# 174142                     ?0100000000000264822                      WL999999
# 174143                     ?0100000000000265380                   XX100013-01
#
#             FLOC_PLTXT_FunctionalLocationDescr  \
# 0                      CALLEMONDAH BLUE ROAD 1
# 1                       Jilalan Provisioning 1
# 2                       Jilalan Provisioning 1
# 3                 NOGOA YARD BLUE ROAD TRACK 1
# 4                    PARANA BLUE ROAD MAINLINE
# ...                                        ...
# 174139  Baralaba WB Strain Gauge Equip 4.225Km
# 174140        Baralaba WB Location Box 4.225Km
# 174141        Baralaba WB Location Box 4.165Km
# 174142         Electric WLNL 01CR BYAA16.652Km
# 174143                  Bridge 9.280km TRACK 1
#
#        FLOC_TYPTX_FunctionalLocationCategoryDescr  \
# 0                                           Track
# 1                                           Track
# 2                                           Track
# 3                                           Track
# 4                                           Track
# ...                                           ...
# 174139                         Telecommunications
# 174140                         Telecommunications
# 174141                         Telecommunications
# 174142               Bridges and other Structures
# 174143               Bridges and other Structures
#
#        FLOC_EQART_TechnicalObjectType FLOC_EARTX_TechnicalObjectTypeDescr  \
# 0                               10003                          Yard Track
# 1                               10003                          Yard Track
# 2                              999999                  Lvl 3 Segmentation
# 3                               10003                          Yard Track
# 4                               10001                           Main Line
# ...                               ...                                 ...
# 174139                          40000                    Wayleave Objects
# 174140                          40000                    Wayleave Objects
# 174141                          40000                    Wayleave Objects
# 174142                          40000                    Wayleave Objects
# 174143                          20010                             Bridges
#
#        FLOC_BUKRS_CompanyCode FLOC_STORT_Location FLOC_STORT_LocationDescr
# 0                        5000              CA0089              Callemondah
# 1                        5000              JI0204                  Jilalan
# 2                        5000              JI0204                  Jilalan
# 3                        5000              NO0275             Nogoa-Yamala
# 4                        5000              PA0289                   Parana
# ...                       ...                 ...                      ...
# 174139                   5000              BA0032                 Baralaba
# 174140                   5000              BA0032                 Baralaba
# 174141                   5000              BA0032                 Baralaba
# 174142                   5000              AR0021           Armuna-Buckley
# 174143                   5000                                         None
#
# [174144 rows x 9 columns]

# %%
df_all_floc.duplicated(subset=['FLOC_STRNO_FunctionalLocation']).sum()
# Out:
# 0
