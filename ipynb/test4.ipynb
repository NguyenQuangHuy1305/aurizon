# %%
import pandas as pd

df1 = pd.read_pickle('pkl/asset_renewal_all_11032024.pkl')
df1
# Out:
#         FuncLocID           Asset Type  \
# 0     LX000659-95  Asset Type Crossing
# 1     LX000661-91  Asset Type Crossing
# 2        LX000750  Asset Type Crossing
# 3        LX000640  Asset Type Crossing
# 4        LX000758  Asset Type Crossing
# ...           ...                  ...
# 4791  ST009540-02  Asset Type Oveahead
# 4792  ST009510-02  Asset Type Oveahead
# 4793  ST007820-04  Asset Type Oveahead
# 4794  ST007870-02  Asset Type Oveahead
# 4795  ST008530-04  Asset Type Oveahead
#
#                                                   Asset FuncLocLinearLengthKM  \
# 0     Public Level Xing Refurbishment (signage, drai...                 0.000
# 1     Public Level Xing Refurbishment (signage, drai...                 0.000
# 2     Public Level Xing Refurbishment (signage, drai...                 0.000
# 3     Public Level Xing Refurbishment (signage, drai...                 0.000
# 4     Public Level Xing Refurbishment (signage, drai...                 0.000
# ...

# %%
df2 = pd.read_pickle('pkl/flocs_joined_to_linecode.pkl')
df2
# Out:
#        FLOC_STRNO_FunctionalLocation      FLOC_PLTXT_FunctionalLocationDescr  \
# 477                  PN-ZZ-EM-HEL025         HEL025 SKID STEER LOADER C64591
# 488                  PN-SP-EM-KEL025   KEL025 SKID STEER WHEEL LOADER C72329
# 489                  PN-SP-EM-KEL026  KEL026 WHEEL LOADER VOLVO L120F C75196
# 922                          GA-47YR                          SARAJI MAT YD2
# 924                     GA-05CR-VAVA                             VILLAFRANCA
# ...                              ...                                     ...
# 161588           MA-02FK-CHBE-DE0020                DE400868_MA02FK0_MA02FK0
# 161590           MA-02PL-SESE-DE0010              DE400871_MA02PL24_MA02PL24
# 161591           MA-03FK-BEGE-DE0010                DE400872_MA03FK0_MA03FK0
# 161592           MA-03FK-BEGE-DE0020                DE400873_MA03FK0_MA03FK1
# 161593           MA-03FK-BEGE-DE0030                DE400874_MA03FK0_MA03FK1
#
# ...

# %%
df3 = pd.read_pickle('pkl/nsap_renewal_assets_linked.pkl')
df3
# Out:
#       FLOC_STRNO_FunctionalLocation           Asset Type  \
# 0                       LX000659-95  Asset Type Crossing
# 1                       LX000661-91  Asset Type Crossing
# 2                          LX000750  Asset Type Crossing
# 3                          LX000640  Asset Type Crossing
# 4                          LX000758  Asset Type Crossing
# ...                             ...                  ...
# 43084                   ST009540-02  Asset Type Oveahead
# 43085                   ST009510-02  Asset Type Oveahead
# 43086                   ST007820-04  Asset Type Oveahead
# 43087                   ST007870-02  Asset Type Oveahead
# 43088                   ST008530-04  Asset Type Oveahead
#
#                                                    Asset  \
# 0      Public Level Xing Refurbishment (signage, drai...
# 1      Public Level Xing Refurbishment (signage, drai...
# 2      Public Level Xing Refurbishment (signage, drai...
# ...
