# %%
import pandas as pd
import pyodbc
from datetime import datetime

# %%
sql_query = """
    -- all WO and their flocid
    SELECT
        [WorkOrderNumber],
        [OrderType],
        [CompanyCode],
        [FunctionLocation],
        CASE
            WHEN [TechCompletionDate] IS NULL THEN [BasicFinishDate]
            ELSE [TechCompletionDate]
        END AS 'CompletionDate',
        [MaintenanceActivityType],
        [MaintenanceActivityTypeDesc],
        [MainUserStatus],
        [MainUserStatusDesc],
        [ActualTotalCost],
        [WBSElementSAP]
    FROM [myANALYTICS_SP].[bronze.batch.belowrail.asset.ringfenced].[vw_WorkOrder]
    WHERE
        [MaintenanceActivityType] IN
            (
                'C01', 'C14', 'C20', 'C02', 'C13', 'C03', 'C19', 'C23', 'C25', 'C26', 'C10', -- Mechanised Track Maintenance
                'C29', 'C31', 'T31', 'C37', 'C08', 'C47', 'C54', 'C43', 'C51', 'C53', 'C57', 'C70', 'C72', 'C50', 'C10', 'C30', 'C48', 'C54', 'C52', 'C06', 'C07', 'C44', 'C01', 'C41', -- General Track Maintenance
                'NIP', 'NRP', 'B50', 'B53', 'C67', 'B04', 'B05', 'B06', 'B55', 'B57', -- Structures Maintenance
                'T28', 'T29', 'T33', 'T40', 'T41', 'T58', 'T44', 'T45', 'T34', 'T46', 'T47', 'T48', 'T54', 'T42', 'T43', -- Control Systems - Signalling and Wayside Maintenance
                'T10', 'T11', 'T32', -- Control Systems - Telecommunications Maintenance
                'C54', 'T32', -- Control Systems - Operational Systems Maintenance
                'T26', 'T27', 'NSV', 'T32', 'T24', 'T25', 'E31' -- Traction Power Maintenance
            )
        AND [CompanyCode] = '5000'
        AND [MainUserStatusDesc] = 'Practically Completed'
        AND [ActualTotalCost] IS NOT NULL
        AND [ActualTotalCost] > 0
        AND OrderType <> 'MW04'
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';DATABASE=myANALYTICS_SP;Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df1 = pd.read_sql_query(sql_query, conn)

df1.to_pickle("../pkl/work_order_main_all.pkl")
# Display the DataFrame
df1
# Out:
# C:\Users\R893859\AppData\Local\Temp\ipykernel_22684\3544076196.py:43: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query(sql_query, conn)
#       WorkOrderNumber OrderType CompanyCode FunctionLocation CompletionDate  \
# 0        000057080030      NW02        5000         TO000619     2024-05-16
# 1        000057080032      NW02        5000         TO000619     2024-05-16
# 2        000057080178      NW02        5000          GA-01ML     2024-06-28
# 3        000057080395      NW02        5000      LX003289-91     2024-04-15
# 4        000058280231      NW03        5000      ST001740-02     2024-03-28
# ...               ...       ...         ...              ...            ...
# 14504    000058268354      NW03        5000      TO000774-01     2024-05-09
# 14505    000058268355      NW03        5000      TO000775-01     2024-05-09
# 14506    000058268356      NW03        5000      TO000711-01     2024-05-29
# 14507    000058268369      NW03        5000      TO000247-02     2024-05-02
# 14508    000058268370      NW03        5000      TO000303-01     2024-05-02
#
#       MaintenanceActivityType     MaintenanceActivityTypeDesc MainUserStatus  \
# 0                         C10             Turnout Maintenance           PCOM
# 1                         C10             Turnout Maintenance           PCOM
# 2                         C70            Corridor Maintenance           PCOM
# 3                         C57      Level Crossing Maintenance           PCOM
# 4                         E31  Feed Stns&Trck Sect Cabin Mtce           PCOM
# ...                       ...                             ...            ...
# 14504                     T33    Signalling Field Maintenance           PCOM
# 14505                     T33    Signalling Field Maintenance           PCOM
# 14506                     T33    Signalling Field Maintenance           PCOM
# 14507                     T33    Signalling Field Maintenance           PCOM
# 14508                     T33    Signalling Field Maintenance           PCOM
#
#           MainUserStatusDesc  ActualTotalCost
# 0      Practically Completed          1883.38
# 1      Practically Completed          6532.42
# 2      Practically Completed          1338.34
# 3      Practically Completed          2099.18
# 4      Practically Completed           436.54
# ...                      ...              ...
# 14504  Practically Completed           569.18
# 14505  Practically Completed           711.46
# 14506  Practically Completed          1328.07
# 14507  Practically Completed           525.81
# 14508  Practically Completed           525.81
#
# [14509 rows x 10 columns]

# %%
# Getting all FLOC from [vw_Dim_FunctionalLocation] where CompanyCode = 5000 -> df2_no_length
sql_query = """
    SELECT
        FLOC_STRNO_FunctionalLocation,
        FLOC_PLTXT_FunctionalLocationDescr,
        FLOC_EARTX_TechnicalObjectTypeDescr,
        FLOC_STORT_LocationDescr
    FROM [myANALYTICS_SP].[silver.dimension.enterprise.asset].[vw_Dim_FunctionalLocation]
	WHERE
        FLOC_BUKRS_CompanyCode = '5000'
	ORDER BY FLOC_STRNO_FunctionalLocation
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df2 = pd.read_sql_query(sql_query, conn)

df2
# Out:
# C:\Users\R893859\AppData\Local\Temp\ipykernel_23704\1361096898.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql_query(sql_query, conn)
#        FLOC_STRNO_FunctionalLocation      FLOC_PLTXT_FunctionalLocationDescr  \
# 0                            AC-01CH                 CALLEMONDAH BLUE ROAD 1
# 1                            AC-01JN                  Jilalan Provisioning 1
# 2                       AC-01JN-JNJN                  Jilalan Provisioning 1
# 3                            AC-01NA            NOGOA YARD BLUE ROAD TRACK 1
# 4                            AC-01PA               PARANA BLUE ROAD MAINLINE
# ...                              ...                                     ...
# 174445                      WL000203  Baralaba WB Strain Gauge Equip 4.225Km
# 174446                      WL000204        Baralaba WB Location Box 4.225Km
# 174447                      WL000205        Baralaba WB Location Box 4.165Km
# 174448                      WL999999         Electric WLNL 01CR BYAA16.652Km
# 174449                   XX100013-01                  Bridge 9.280km TRACK 1
#
#        FLOC_EARTX_TechnicalObjectTypeDescr FLOC_STORT_LocationDescr
# 0                               Yard Track              Callemondah
# 1                               Yard Track                  Jilalan
# 2                       Lvl 3 Segmentation                  Jilalan
# 3                               Yard Track             Nogoa-Yamala
# 4                                Main Line                   Parana
# ...                                    ...                      ...
# 174445                    Wayleave Objects                 Baralaba
# 174446                    Wayleave Objects                 Baralaba
# 174447                    Wayleave Objects                 Baralaba
# 174448                    Wayleave Objects           Armuna-Buckley
# 174449                             Bridges                     None
#
# [174450 rows x 4 columns]

# %%
# df2 = pd.read_pickle(r'C:\Users\R893859\Aurizon Operations Limited\Data, Reporting & Analytics - DS08 - NSAP2\Data\Huy\Flocs List\maint_flocs.pkl')
# df2
# Out:
#          FuncLocID                                Maintenance Product
# 0      TO000226-01  Points (mechanical, electric, electro-hydrauli...
# 2      TO000226-02  Points (mechanical, electric, electro-hydrauli...
# 4      LX006284-01                     Level Crossing Warning Control
# 7      TO000310-01  Points (mechanical, electric, electro-hydrauli...
# 9      TO000147-01  Points (mechanical, electric, electro-hydrauli...
# ...            ...                                                ...
# 76328  ST008155-15                          Power Supplies (Electric)
# 76330  ST008155-19                          Power Supplies (Electric)
# 76332  ST008155-22                          Power Supplies (Electric)
# 76334  ST009535-06                          Power Supplies (Electric)
# 76336  ST009535-12                          Power Supplies (Electric)
#
# [60855 rows x 2 columns]

# %%
all_main_type_df = pd.DataFrame(df2['FLOC_EARTX_TechnicalObjectTypeDescr'].unique(), columns=['FLOC_EARTX_TechnicalObjectTypeDescr'])
all_main_type_df
# Out:
#     FLOC_EARTX_TechnicalObjectTypeDescr
# 0                            Yard Track
# 1                    Lvl 3 Segmentation
# 2                             Main Line
# 3                    Corridor Access Pt
# 4                      Corridor Objects
# ..                                  ...
# 252                       Turnout Track
# 253                      Manual Turnout
# 254                Points Remote Contro
# 255                      Points Locking
# 256                    Wayleave Objects
#
# [257 rows x 1 columns]

# %%
merged_df = pd.merge(df1, df2, how='left', left_on='FunctionLocation', right_on='FLOC_STRNO_FunctionalLocation')
merged_df
# Out:
#       WorkOrderNumber OrderType CompanyCode FunctionLocation CompletionDate  \
# 0        000058280231      NW03        5000      ST001740-02     2024-03-28
# 1        000058280232      NW03        5000      ST001750-02     2024-03-28
# 2        000058280233      NW03        5000      ST001760-02     2024-03-28
# 3        000058280234      NW03        5000      ST001770-02     2024-04-11
# 4        000058280235      NW03        5000      ST000760-14     2024-03-28
# ...               ...       ...         ...              ...            ...
# 17429    000058266105      NW03        5000      TO000449-01     2024-04-04
# 17430    000058266178      NW03        5000      TO000770-01     2024-04-11
# 17431    000058266180      NW03        5000      TO000966-01     2024-03-31
# 17432    000058266181      NW03        5000      TO000964-01     2024-03-31
# 17433    000058266192      NW03        5000      ST007810-07     2024-06-20
#
#       MaintenanceActivityType     MaintenanceActivityTypeDesc MainUserStatus  \
# 0                         E31  Feed Stns&Trck Sect Cabin Mtce           PCOM
# 1                         E31  Feed Stns&Trck Sect Cabin Mtce           PCOM
# 2                         E31  Feed Stns&Trck Sect Cabin Mtce           PCOM
# 3                         E31  Feed Stns&Trck Sect Cabin Mtce           PCOM
# 4                         E31  Feed Stns&Trck Sect Cabin Mtce           PCOM
# ...                       ...                             ...            ...
# 17429                     T33    Signalling Field Maintenance           PCOM
# 17430                     T33    Signalling Field Maintenance           PCOM
# 17431                     T33    Signalling Field Maintenance           PCOM
# 17432                     T33    Signalling Field Maintenance           PCOM
# 17433                     T46         Weighbridge Maintenance           PCOM
#
#           MainUserStatusDesc  ActualTotalCost FLOC_STRNO_FunctionalLocation  \
# 0      Practically Completed           436.54                   ST001740-02
# 1      Practically Completed           436.54                   ST001750-02
# 2      Practically Completed           436.54                   ST001760-02
# 3      Practically Completed          1458.02                   ST001770-02
# 4      Practically Completed           436.54                   ST000760-14
# ...                      ...              ...                           ...
# 17429  Practically Completed          2790.09                   TO000449-01
# 17430  Practically Completed           379.45                   TO000770-01
# 17431  Practically Completed           761.37                   TO000966-01
# 17432  Practically Completed           380.70                   TO000964-01
# 17433  Practically Completed          8122.58                   ST007810-07
#
#           FLOC_PLTXT_FunctionalLocationDescr  \
# 0            PD 43.789 Km AC/DC Power Supply
# 1         Dysart  88.4 km OC battery charger
# 2        Saraji 65.146 km OC battery charger
# 3      Bundoora 129.64 km OC battery charger
# 4         GC TSC 136.4 Km AC/DC Power Supply
# ...                                      ...
# 17429                               HD8A Pts
# 17430                         YA ER1 Frame C
# 17431                        DA TFP 16.398Km
# 17432                          DA TFP 15.0Km
# 17433              Boundary Hill Weighbridge
#
#       FLOC_EARTX_TechnicalObjectTypeDescr FLOC_STORT_LocationDescr
# 0                        LV Power Systems               Peak Downs
# 1                        LV Power Systems                   Dysart
# 2                        LV Power Systems                   Saraji
# 3                        LV Power Systems                 Bundoora
# 4                        LV Power Systems             German Creek
# ...                                   ...                      ...
# 17429                     Electric Points                 Hatfield
# 17430                Train Control System                   Yamala
# 17431                   Mechanical Points                  Dakenba
# 17432                   Mechanical Points                  Dakenba
# 17433                Electronic Weighbrid                Annandale
#
# [17434 rows x 14 columns]

# %%
# Convert CompletionDate column into datetime
merged_df['CompletionDate'] = pd.to_datetime(merged_df['CompletionDate'])
# merged_df['Asset Type'] = merged_df['Asset Type'].fillna('Unknown')

# Calculate all time average
grouped_all_time = merged_df.groupby('FLOC_EARTX_TechnicalObjectTypeDescr').agg(
    Average_ActualTotalCost_All_Time=('ActualTotalCost', 'mean'),
    Sample_Size_All_Time=('FLOC_EARTX_TechnicalObjectTypeDescr', 'size')
).reset_index()

grouped_all_time
# Out:
#     FLOC_EARTX_TechnicalObjectTypeDescr  Average_ActualTotalCost_All_Time  \
# 0                           AC/DC Track                       1272.205000
# 1                                   ATP                       1376.613611
# 2                  Acoustic Detector Sy                       1710.461667
# 3                  Alternator Control E                       2636.046000
# 4                               Antenna                       6365.990000
# ..                                  ...                               ...
# 100                Weather Station Syst                        792.230909
# 101                Westinghouse Telemet                       1894.536667
# 102                Westrace Interlockin                       2586.375000
# 103                Wheel Impact Load De                       4686.633077
# 104                          Yard Track                       2678.006969
#
#      Sample_Size_All_Time
# 0                       2
# 1                      36
# 2                       6
# 3                       5
# 4                       1
# ..                    ...
# 100                    11
# 101                     3
# 102                     8
# 103                    13
# 104                   287
#
# [105 rows x 3 columns]

# %%
# Calculate last year average
current_year = datetime.now().year
previous_year = current_year - 1

df_previous_year = merged_df[merged_df['CompletionDate'].dt.year == previous_year]

grouped_previous_year = df_previous_year.groupby('FLOC_EARTX_TechnicalObjectTypeDescr').agg(
    Average_ActualTotalCost_Previous_Year=('ActualTotalCost', 'mean'),
    Sample_Size_Previous_Year=('FLOC_EARTX_TechnicalObjectTypeDescr', 'size')
).reset_index()

grouped_previous_year
# Out:
#    FLOC_EARTX_TechnicalObjectTypeDescr  Average_ActualTotalCost_Previous_Year  \
# 0                              Battery                             723.520000
# 1                              Bridges                            9608.626667
# 2                                  CER                            1849.640000
# 3                     Connecting Track                           32541.030000
# 4                     Corridor Objects                            6564.000000
# 5                           Crossovers                           16321.146667
# 6                             Culverts                            5438.633784
# 7                  Curves - Med Radius                            2732.116667
# 8                          DED Systems                             350.560000
# 9                      Electric Points                           25895.873333
# 10                     Electric Signal                            1726.450000
# 11                  Electrical Section                           45167.000000
# 12                  Electrical Turnout                           57661.965586
# 13                Electronic Weighbrid                            4120.275000
# 14                                Fork                           14030.840000
# 15                                 GIJ                            3621.387500
# 16                       HV Monitoring                             276.670000
# 17                             Housing                            1168.680000
# 18                           Isolators                           49432.001538
# 19                     Jointless Track                            5643.540000
# 20                    LV Power Systems                            2544.145000
# 21                      Level Crossing                            1072.872727
# 22                    Loading Facility                          287195.549524
# 23                Loadout Alarm System                             682.280000
# 24                  Lvl 3 Segmentation                            3994.595000
# 25                           Main Line                          260158.964571
# 26                      Maintenance LX                            2200.530000
# 27                      Manual Turnout                           31150.930000
# 28                   Mechanical Points                             880.516667
# 29                        Passing Loop                          138967.330000
# 30                       Power Quality                            5044.440000
# 31                          Private LX                           20958.066000
# 32                           Public LX                            3245.517500
# 33                         SFC Cooling                           16044.490000
# 34                   Section Insulator                            4904.306667
# 35                      Standby Supply                            1157.180000
# 36                     Structure Track                          120871.297955
# 37                          Substation                             260.020000
# 38                         Supervisory                            4761.290000
# 39                Train Control System                             969.094000
# 40                         Transformer                            1174.340000
# 41                  Unloading Facility                          220342.312000
# 42                             Wayside                            5125.410000
# 43                Westrace Interlockin                            5851.420000
# 44                          Yard Track                           11098.205000
#
#     Sample_Size_Previous_Year
# 0                           1
# 1                           3
# 2                           1
# 3                           1
# 4                           1
# 5                           3
# 6                          37
# 7                           3
# 8                           1
# 9                           3
# 10                          3
# 11                          3
# 12                        145
# 13                          2
# 14                          1
# 15                          4
# 16                          1
# 17                          4
# 18                         13
# 19                          1
# 20                          2
# 21                         11
# 22                         21
# 23                          1
# 24                          2
# 25                         70
# 26                          2
# 27                         12
# 28                          9
# 29                          4
# 30                          1
# 31                          5
# 32                          4
# 33                          1
# 34                          3
# 35                          6
# 36                         44
# 37                          1
# 38                          1
# 39                         10
# 40                          2
# 41                         10
# 42                          1
# 43                          1
# 44                          4

# %%
# Calculate last 3 years average
last_3_years_start = current_year - 3

df_last_3_years = merged_df[(merged_df['CompletionDate'].dt.year >= last_3_years_start) & (merged_df['CompletionDate'].dt.year != current_year)]

grouped_last_3_years = df_last_3_years.groupby('FLOC_EARTX_TechnicalObjectTypeDescr').agg(
    Average_Last_3_Years=('ActualTotalCost', 'mean'),
    Sample_Size_Last_3_Years=('FLOC_EARTX_TechnicalObjectTypeDescr', 'size')
).reset_index()

grouped_last_3_years
# Out:
#    FLOC_EARTX_TechnicalObjectTypeDescr  Average_Last_3_Years  \
# 0                 Axle Counter Detecti           1343.580000
# 1                              Battery            723.520000
# 2                              Bridges         145760.992500
# 3                                  CER           1849.640000
# 4                               Cables           1733.440000
# 5                     Conductors/Wires         172306.170000
# 6                     Connecting Track          32541.030000
# 7                     Corridor Objects           6564.000000
# 8                           Crossovers          16321.146667
# 9                             Culverts           5348.527105
# 10                 Curves - Lrg Radius           1576.080000
# 11                 Curves - Med Radius           1881.940000
# 12                         DED Systems            350.560000
# 13                     Electric Points          16444.085000
# 14                     Electric Signal           3436.278000
# 15                  Electrical Section          26313.381579
# 16                  Electrical Turnout          40004.424193
# 17                Electronic Weighbrid           3554.980000
# 18                                Fork          14030.840000
# 19                                 GIJ           2976.685000
# 20                       HV Monitoring            276.670000
# 21                             Housing           2301.650000
# 22                    Hydraulic Points          11722.387500
# 23                          Insulators           6435.040000
# 24                           Isolators          38018.967273
# 25                     Jointless Track           3341.783333
# 26                    LV Power Systems           4282.882727
# 27                      Level Crossing           1072.872727
# 28                    Loading Facility         182196.797391
# 29                Loadout Alarm System            682.280000
# 30                  Lvl 3 Segmentation           3994.595000
# 31                Lvl4 Feature Locatio          12354.376667
# 32                Lvl5 Feature Locatio           6524.674828
# 33                           Main Line         194890.040789
# 34                      Maintenance LX           2200.530000
# 35                      Manual Turnout          30053.856000
# 36                   Mechanical Points            880.516667
# 37                        Passing Loop         191973.443750
# 38                       Power Quality           5044.440000
# 39                          Private LX          20958.066000
# 40                           Public LX           3059.116000
# 41                         SFC Cooling          16044.490000
# 42                   Section Insulator          38660.890000
# 43                                Site           4817.510000
# 44                      Standby Supply          12812.005714
# 45                     Structure Track          90866.629407
# 46                          Substation            647.185000
# 47                         Supervisory           4761.290000
# 48                Train Control System           3899.289091
# 49                         Transformer          11579.542000
# 50                  Unloading Facility         138746.322353
# 51                             Wayside           4488.890000
# 52                Westrace Interlockin           5851.420000
# 53                          Yard Track          15156.684000
#
#     Sample_Size_Last_3_Years
# 0                          1
# 1                          1
# 2                          4
# 3                          1
# 4                          1
# 5                          1
# 6                          1
# 7                          1
# 8                          3
# 9                         38
# 10                         1
# 11                         5
# 12                         1
# 13                        16
# 14                         5
# 15                        19
# 16                       322
# 17                         4
# 18                         1
# 19                         6
# 20                         1
# 21                         8
# 22                         4
# 23                         1
# 24                        22
# 25                         3
# 26                        11
# 27                        11
# 28                        46
# 29                         1
# 30                         2
# 31                         3
# 32                        87
# 33                       152
# 34                         2
# 35                        35
# 36                         9
# 37                         8
# 38                         1
# 39                         5
# 40                         5
# 41                         1
# 42                         4
# 43                         2
# 44                         7
# 45                       118
# 46                         2
# 47                         1
# 48                        11
# 49                         5
# 50                        17
# 51                         2
# 52                         1
# 53                         5

# %%
# Calculate last 5 years average
last_5_years_start = current_year - 5

df_last_5_years = merged_df[(merged_df['CompletionDate'].dt.year >= last_5_years_start) & (merged_df['CompletionDate'].dt.year != current_year)]

grouped_last_5_years = df_last_5_years.groupby('FLOC_EARTX_TechnicalObjectTypeDescr').agg(
    Average_Last_5_Years=('ActualTotalCost', 'mean'),
    Sample_Size_Last_5_Years=('FLOC_EARTX_TechnicalObjectTypeDescr', 'size')
).reset_index()

grouped_last_5_years
# Out:
#    FLOC_EARTX_TechnicalObjectTypeDescr  Average_Last_5_Years  \
# 0                 Axle Counter Detecti           1343.580000
# 1                              Battery            723.520000
# 2                              Bridges          66407.328750
# 3                                  CER           1849.640000
# 4                               Cables           1733.440000
# 5                     Conductors/Wires         172306.170000
# 6                     Connecting Track          32541.030000
# 7                     Corridor Objects          30144.002000
# 8                           Crossovers          16321.146667
# 9                             Culverts           5524.835641
# 10                 Curves - Lrg Radius           1576.080000
# 11                 Curves - Med Radius           1881.940000
# 12                         DED Systems            350.560000
# 13                     Electric Points          14319.652632
# 14                     Electric Signal           3436.278000
# 15                  Electrical Section          31688.469000
# 16                  Electrical Turnout          35839.002301
# 17                Electronic Weighbrid           3554.980000
# 18                                Fork          14030.840000
# 19                                 GIJ           2976.685000
# 20                       HV Monitoring            276.670000
# 21                             Housing           2980.681000
# 22                    Hydraulic Points          11722.387500
# 23                          Insulators           6435.040000
# 24                           Isolators          38018.967273
# 25                     Jointless Track           3851.702857
# 26                    LV Power Systems           4282.882727
# 27                      Level Crossing           1072.872727
# 28                    Loading Facility         153290.084727
# 29                Loadout Alarm System            682.280000
# 30                  Lvl 3 Segmentation           3994.595000
# 31                Lvl4 Feature Locatio          12354.376667
# 32                Lvl5 Feature Locatio           6731.000818
# 33                           Main Line         166634.793128
# 34                      Maintenance LX           2200.530000
# 35                      Manual Turnout          26088.565610
# 36                   Mechanical Points            880.516667
# 37                        Passing Loop         191973.443750
# 38                       Power Quality           5044.440000
# 39                          Private LX          20958.066000
# 40                           Public LX           3059.116000
# 41                         SFC Cooling          16044.490000
# 42                   Section Insulator          38660.890000
# 43                                Site           3201.800000
# 44                      Standby Supply          12812.005714
# 45                     Structure Track          90647.303333
# 46                          Substation            647.185000
# 47                         Supervisory           4761.290000
# 48                Train Control System           3899.289091
# 49                         Transformer          11579.542000
# 50                  Unloading Facility         138746.322353
# 51                             Wayside           4488.890000
# 52                Westrace Interlockin           5851.420000
# 53                          Yard Track          15156.684000
#
#     Sample_Size_Last_5_Years
# 0                          1
# 1                          1
# 2                         16
# 3                          1
# 4                          1
# 5                          1
# 6                          1
# 7                          5
# 8                          3
# 9                         39
# 10                         1
# 11                         5
# 12                         1
# 13                        19
# 14                         5
# 15                        20
# 16                       365
# 17                         4
# 18                         1
# 19                         6
# 20                         1
# 21                        10
# 22                         4
# 23                         1
# 24                        22
# 25                         7
# 26                        11
# 27                        11
# 28                        55
# 29                         1
# 30                         2
# 31                         3
# 32                       110
# 33                       179
# 34                         2
# 35                        41
# 36                         9
# 37                         8
# 38                         1
# 39                         5
# 40                         5
# 41                         1
# 42                         4
# 43                         5
# 44                         7
# 45                       123
# 46                         2
# 47                         1
# 48                        11
# 49                         5
# 50                        17
# 51                         2
# 52                         1
# 53                         5

# %%
result_df = pd.merge(grouped_all_time, grouped_previous_year, on='FLOC_EARTX_TechnicalObjectTypeDescr', how='left')
result_df = pd.merge(result_df, grouped_last_3_years, on='FLOC_EARTX_TechnicalObjectTypeDescr', how='left')
result_df = pd.merge(result_df, grouped_last_5_years, on='FLOC_EARTX_TechnicalObjectTypeDescr', how='left')

result_df
# Out:
#     FLOC_EARTX_TechnicalObjectTypeDescr  Average_ActualTotalCost_All_Time  \
# 0                           AC/DC Track                       1272.205000
# 1                                   ATP                       1376.613611
# 2                  Acoustic Detector Sy                       1710.461667
# 3                  Alternator Control E                       2636.046000
# 4                               Antenna                       6365.990000
# ..                                  ...                               ...
# 100                Weather Station Syst                        792.230909
# 101                Westinghouse Telemet                       1894.536667
# 102                Westrace Interlockin                       2586.375000
# 103                Wheel Impact Load De                       4686.633077
# 104                          Yard Track                       2678.006969
#
#      Sample_Size_All_Time  Average_ActualTotalCost_Previous_Year  \
# 0                       2                                    NaN
# 1                      36                                    NaN
# 2                       6                                    NaN
# 3                       5                                    NaN
# 4                       1                                    NaN
# ..                    ...                                    ...
# 100                    11                                    NaN
# 101                     3                                    NaN
# 102                     8                               5851.420
# 103                    13                                    NaN
# 104                   287                              11098.205
#
#      Sample_Size_Previous_Year  Average_Last_3_Years  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# ..                         ...                   ...
# 100                        NaN                   NaN
# 101                        NaN                   NaN
# 102                        1.0              5851.420
# 103                        NaN                   NaN
# 104                        4.0             15156.684
#
#      Sample_Size_Last_3_Years  Average_Last_5_Years  Sample_Size_Last_5_Years
# 0                         NaN                   NaN                       NaN
# 1                         NaN                   NaN                       NaN
# 2                         NaN                   NaN                       NaN
# 3                         NaN                   NaN                       NaN
# 4                         NaN                   NaN                       NaN
# ..                        ...                   ...                       ...
# 100                       NaN                   NaN                       NaN
# 101                       NaN                   NaN                       NaN
# 102                       1.0              5851.420                       1.0
# 103                       NaN                   NaN                       NaN
# 104                       5.0             15156.684                       5.0
#
# [105 rows x 9 columns]

# %%
result_df = pd.merge(all_main_type_df, result_df, on='FLOC_EARTX_TechnicalObjectTypeDescr', how='left')
result_df.to_pickle("../pkl/average_main_cost.pkl")

result_df
# Out:
#     FLOC_EARTX_TechnicalObjectTypeDescr  Average_ActualTotalCost_All_Time  \
# 0                            Yard Track                       2678.006969
# 1                    Lvl 3 Segmentation                       3996.588000
# 2                             Main Line                      29359.375601
# 3                    Corridor Access Pt                       7668.270000
# 4                      Corridor Objects                       6405.312363
# ..                                  ...                               ...
# 252                       Turnout Track                               NaN
# 253                      Manual Turnout                       5364.094444
# 254                Points Remote Contro                       2237.895000
# 255                      Points Locking                       2467.380000
# 256                    Wayleave Objects                               NaN
#
#      Sample_Size_All_Time  Average_ActualTotalCost_Previous_Year  \
# 0                   287.0                           11098.205000
# 1                     5.0                            3994.595000
# 2                  1439.0                          260158.964571
# 3                     1.0                                    NaN
# 4                   347.0                            6564.000000
# ..                    ...                                    ...
# 252                   NaN                                    NaN
# 253                 288.0                           31150.930000
# 254                   2.0                                    NaN
# 255                   2.0                                    NaN
# 256                   NaN                                    NaN
#
#      Sample_Size_Previous_Year  Average_Last_3_Years  \
# 0                          4.0          15156.684000
# 1                          2.0           3994.595000
# 2                         70.0         194890.040789
# 3                          NaN                   NaN
# 4                          1.0           6564.000000
# ..                         ...                   ...
# 252                        NaN                   NaN
# 253                       12.0          30053.856000
# 254                        NaN                   NaN
# 255                        NaN                   NaN
# 256                        NaN                   NaN
#
#      Sample_Size_Last_3_Years  Average_Last_5_Years  Sample_Size_Last_5_Years
# 0                         5.0          15156.684000                       5.0
# 1                         2.0           3994.595000                       2.0
# 2                       152.0         166634.793128                     179.0
# 3                         NaN                   NaN                       NaN
# 4                         1.0          30144.002000                       5.0
# ..                        ...                   ...                       ...
# 252                       NaN                   NaN                       NaN
# 253                      35.0          26088.565610                      41.0
# 254                       NaN                   NaN                       NaN
# 255                       NaN                   NaN                       NaN
# 256                       NaN                   NaN                       NaN
#
# [257 rows x 9 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
