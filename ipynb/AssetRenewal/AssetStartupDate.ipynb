# %%
import pandas as pd
import pyodbc
from datetime import datetime

# %%
sql_query = """
    -- all WO and their flocid
    SELECT
        [WorkOrderNumber],
        [OrderType],
        [CompanyCode],
        [FunctionLocation],
        CASE
            WHEN [TechCompletionDate] IS NULL THEN [BasicFinishDate]
            ELSE [TechCompletionDate]
        END AS 'CompletionDate',
        [MaintenanceActivityType],
        [MaintenanceActivityTypeDesc],
        [MainUserStatus],
        [MainUserStatusDesc],
        [ActualTotalCost]
    FROM [myANALYTICS_SP].[bronze.batch.belowrail.asset.ringfenced].[vw_WorkOrder]
    WHERE
        OrderType = 'MW04'
        AND CompanyCode = '5000'
        AND MainUserStatusDesc = 'Practically Completed'
        AND ActualTotalCost IS NOT NULL
        AND ActualTotalCost > 0
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';DATABASE=myANALYTICS_SP;Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df1 = pd.read_sql_query(sql_query, conn)

df1.to_pickle("../pkl/work_order_all.pkl")
# Display the DataFrame
df1
# Out:
# C:\Users\R893859\AppData\Local\Temp\ipykernel_1696\3996797468.py:33: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query(sql_query, conn)
#      WorkOrderNumber OrderType CompanyCode FunctionLocation CompletionDate  \
# 0       000080085665      MW04        5000         TO000654     2018-12-19
# 1       000080085667      MW04        5000         TO000470     2018-04-04
# 2       000080085668      MW04        5000         CP000045     2018-05-08
# 3       000080085669      MW04        5000         TO000352     2018-06-01
# 4       000080085670      MW04        5000         TO000483     2018-06-05
# ...              ...       ...         ...              ...            ...
# 9726    000080117443      MW04        5000         LX003196     2024-06-13
# 9727    000080117445      MW04        5000         LX005559     2024-05-29
# 9728    000080116605      MW04        5000          GA-01ML     2024-06-06
# 9729    000080116606      MW04        5000          BW-04PL     2024-05-01
# 9730    000080116769      MW04        5000          GA-01ML     2024-06-06
#
#      MaintenanceActivityType    MaintenanceActivityTypeDesc MainUserStatus  \
# 0                        C16  Turnout Renew Maj Civil Parts           PCOM
# 1                        C16  Turnout Renew Maj Civil Parts           PCOM
# 2                        C16  Turnout Renew Maj Civil Parts           PCOM
# 3                        C16  Turnout Renew Maj Civil Parts           PCOM
# 4                        C16  Turnout Renew Maj Civil Parts           PCOM
# ...                      ...                            ...            ...
# 9726                     C58        Level Xing Refurb/Renew           PCOM
# 9727                     C58        Level Xing Refurb/Renew           PCOM
# 9728                     C21                  Track Upgrade           PCOM
# 9729                     C63                  Joint Renewal           PCOM
# 9730                     C01   Ballast Undercutting Machine           PCOM
#
#          MainUserStatusDesc  ActualTotalCost
# 0     Practically Completed         71132.19
# 1     Practically Completed         60383.24
# 2     Practically Completed          5545.31
# 3     Practically Completed         57677.62
# 4     Practically Completed         50925.56
# ...                     ...              ...
# 9726  Practically Completed         14901.08
# 9727  Practically Completed          1321.59
# 9728  Practically Completed          4180.45
# 9729  Practically Completed         13517.25
# 9730  Practically Completed          9581.63
#
# [9731 rows x 10 columns]

# %%
sql_query = """
    SELECT DISTINCT
        FLOC_STRNO_FunctionalLocation,
        IFLOT_DATAB_StartupDate
    FROM
    myANALYTICS_SP.[workarea.silver.dimension.enterprise.asset].vw_Dim_FunctionalLocationStartupDate
    WHERE IFLOT_DATAB_StartupDate > 0
    AND FLOC_STRNO_FunctionalLocation IS NOT NULL
    AND FLOC_BUKRS_CompanyCode = '5000'
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';DATABASE=myANALYTICS_SP;Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
startupdate_df = pd.read_sql_query(sql_query, conn)

# df1.to_pickle("../pkl/work_order_all.pkl")
# Display the DataFrame
startupdate_df['IFLOT_DATAB_StartupDate'] = pd.to_datetime(startupdate_df['IFLOT_DATAB_StartupDate'])
startupdate_df
# Out:
# C:\Users\R893859\AppData\Local\Temp\ipykernel_1696\2242733206.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   startupdate_df = pd.read_sql_query(sql_query, conn)
#       FLOC_STRNO_FunctionalLocation IFLOT_DATAB_StartupDate
# 0                       ST000480-63              2014-01-01
# 1                       ST000850-48              1994-01-01
# 2                       ST000960-87              1987-01-01
# 3                       ST008220-29              2011-11-16
# 4                       ST003870-03              2013-01-01
# ...                             ...                     ...
# 25938                   ST000600-53              2018-07-01
# 25939                   ST000170-61              2014-01-01
# 25940                   ST004120-17              2016-05-29
# 25941                      TO004059              2021-01-01
# 25942               PN-MP-PG-EEG501              2017-09-28
#
# [25943 rows x 2 columns]

# %%
merged_df3 = pd.merge(startupdate_df, df1, how='left', left_on='FLOC_STRNO_FunctionalLocation', right_on='FunctionLocation')
merged_df3
# Out:
#       FLOC_STRNO_FunctionalLocation IFLOT_DATAB_StartupDate WorkOrderNumber  \
# 0                       ST000480-63              2014-01-01             NaN
# 1                       ST000850-48              1994-01-01             NaN
# 2                       ST000960-87              1987-01-01             NaN
# 3                       ST008220-29              2011-11-16             NaN
# 4                       ST003870-03              2013-01-01             NaN
# ...                             ...                     ...             ...
# 25995                   ST000600-53              2018-07-01             NaN
# 25996                   ST000170-61              2014-01-01             NaN
# 25997                   ST004120-17              2016-05-29             NaN
# 25998                      TO004059              2021-01-01             NaN
# 25999               PN-MP-PG-EEG501              2017-09-28             NaN
#
#       OrderType CompanyCode FunctionLocation CompletionDate  \
# 0           NaN         NaN              NaN            NaN
# 1           NaN         NaN              NaN            NaN
# 2           NaN         NaN              NaN            NaN
# 3           NaN         NaN              NaN            NaN
# 4           NaN         NaN              NaN            NaN
# ...         ...         ...              ...            ...
# 25995       NaN         NaN              NaN            NaN
# 25996       NaN         NaN              NaN            NaN
# 25997       NaN         NaN              NaN            NaN
# 25998       NaN         NaN              NaN            NaN
# 25999       NaN         NaN              NaN            NaN
#
#       MaintenanceActivityType MaintenanceActivityTypeDesc MainUserStatus  \
# 0                         NaN                         NaN            NaN
# 1                         NaN                         NaN            NaN
# 2                         NaN                         NaN            NaN
# 3                         NaN                         NaN            NaN
# 4                         NaN                         NaN            NaN
# ...                       ...                         ...            ...
# 25995                     NaN                         NaN            NaN
# 25996                     NaN                         NaN            NaN
# 25997                     NaN                         NaN            NaN
# 25998                     NaN                         NaN            NaN
# 25999                     NaN                         NaN            NaN
#
#       MainUserStatusDesc  ActualTotalCost
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
# ...                  ...              ...
# 25995                NaN              NaN
# 25996                NaN              NaN
# 25997                NaN              NaN
# 25998                NaN              NaN
# 25999                NaN              NaN
#
# [26000 rows x 12 columns]

# %%
# Getting all FLOC from [vw_Dim_FunctionalLocation] where CompanyCode = 5000 -> df2_no_length
sql_query = """
    SELECT
        FLOC_TPLNR_FunctionalLocationInternalKey,
        FLOC_STRNO_FunctionalLocation,
        FLOC_PLTXT_FunctionalLocationDescr,
        FLOC_TYPTX_FunctionalLocationCategoryDescr,
        FLOC_EQART_TechnicalObjectType,
        FLOC_EARTX_TechnicalObjectTypeDescr,
        FLOC_BUKRS_CompanyCode,
        FLOC_STORT_Location,
        FLOC_STORT_LocationDescr
    FROM [myANALYTICS_SP].[silver.dimension.enterprise.asset].[vw_Dim_FunctionalLocation]
	WHERE FLOC_BUKRS_CompanyCode = '5000'
	ORDER BY FLOC_STRNO_FunctionalLocation
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
all_floc = pd.read_sql_query(sql_query, conn)

# Display the DataFrame
all_floc
# Out:
# C:\Users\R893859\AppData\Local\Temp\ipykernel_1696\2885297627.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   all_floc = pd.read_sql_query(sql_query, conn)
#        FLOC_TPLNR_FunctionalLocationInternalKey FLOC_STRNO_FunctionalLocation  \
# 0                          ?0100000000000387769                       AC-01CH
# 1                          ?0100000000000365741                       AC-01JN
# 2                          ?0100000000000366347                  AC-01JN-JNJN
# 3                          ?0100000000000377748                       AC-01NA
# 4                          ?0100000000000387811                       AC-01PA
# ...                                         ...                           ...
# 174332                     ?0100000000000253349                      WL000203
# 174333                     ?0100000000000253351                      WL000204
# 174334                     ?0100000000000253372                      WL000205
# 174335                     ?0100000000000264822                      WL999999
# 174336                     ?0100000000000265380                   XX100013-01
#
#             FLOC_PLTXT_FunctionalLocationDescr  \
# 0                      CALLEMONDAH BLUE ROAD 1
# 1                       Jilalan Provisioning 1
# 2                       Jilalan Provisioning 1
# 3                 NOGOA YARD BLUE ROAD TRACK 1
# 4                    PARANA BLUE ROAD MAINLINE
# ...                                        ...
# 174332  Baralaba WB Strain Gauge Equip 4.225Km
# 174333        Baralaba WB Location Box 4.225Km
# 174334        Baralaba WB Location Box 4.165Km
# 174335         Electric WLNL 01CR BYAA16.652Km
# 174336                  Bridge 9.280km TRACK 1
#
#        FLOC_TYPTX_FunctionalLocationCategoryDescr  \
# 0                                           Track
# 1                                           Track
# 2                                           Track
# 3                                           Track
# 4                                           Track
# ...                                           ...
# 174332                         Telecommunications
# 174333                         Telecommunications
# 174334                         Telecommunications
# 174335               Bridges and other Structures
# 174336               Bridges and other Structures
#
#        FLOC_EQART_TechnicalObjectType FLOC_EARTX_TechnicalObjectTypeDescr  \
# 0                               10003                          Yard Track
# 1                               10003                          Yard Track
# 2                              999999                  Lvl 3 Segmentation
# 3                               10003                          Yard Track
# 4                               10001                           Main Line
# ...                               ...                                 ...
# 174332                          40000                    Wayleave Objects
# 174333                          40000                    Wayleave Objects
# 174334                          40000                    Wayleave Objects
# 174335                          40000                    Wayleave Objects
# 174336                          20010                             Bridges
#
#        FLOC_BUKRS_CompanyCode FLOC_STORT_Location FLOC_STORT_LocationDescr
# 0                        5000              CA0089              Callemondah
# 1                        5000              JI0204                  Jilalan
# 2                        5000              JI0204                  Jilalan
# 3                        5000              NO0275             Nogoa-Yamala
# 4                        5000              PA0289                   Parana
# ...                       ...                 ...                      ...
# 174332                   5000              BA0032                 Baralaba
# 174333                   5000              BA0032                 Baralaba
# 174334                   5000              BA0032                 Baralaba
# 174335                   5000              AR0021           Armuna-Buckley
# 174336                   5000                                         None
#
# [174337 rows x 9 columns]

# %%
merged_df4 = pd.merge(all_floc, merged_df3, how='right', left_on='FLOC_STRNO_FunctionalLocation', right_on='FLOC_STRNO_FunctionalLocation')
merged_df4 = merged_df4[['FLOC_STRNO_FunctionalLocation', 'IFLOT_DATAB_StartupDate']]

merged_df4 = merged_df4[merged_df4['IFLOT_DATAB_StartupDate'].notnull()]
merged_df4
# Out:
#       FLOC_STRNO_FunctionalLocation IFLOT_DATAB_StartupDate
# 0                       ST000480-63              2014-01-01
# 1                       ST000850-48              1994-01-01
# 2                       ST000960-87              1987-01-01
# 3                       ST008220-29              2011-11-16
# 4                       ST003870-03              2013-01-01
# ...                             ...                     ...
# 26001                   ST000600-53              2018-07-01
# 26002                   ST000170-61              2014-01-01
# 26003                   ST004120-17              2016-05-29
# 26004                      TO004059              2021-01-01
# 26005               PN-MP-PG-EEG501              2017-09-28
#
# [26006 rows x 2 columns]
