# %%
import pandas as pd
import pyodbc
from datetime import datetime
pd.set_option('display.max_rows', 10)

# %%
sql_query = """
    -- all WO and their flocid
    SELECT
        [WorkOrderNumber],
        [OrderType],
        [CompanyCode],
        [FunctionLocation],
        CASE
            WHEN [TechCompletionDate] IS NULL THEN [BasicFinishDate]
            ELSE [TechCompletionDate]
        END AS 'CompletionDate',
        [MaintenanceActivityType],
        [MaintenanceActivityTypeDesc],
        [MainUserStatus],
        [MainUserStatusDesc],
        [ActualTotalCost]
    FROM [myANALYTICS_SP].[bronze.batch.belowrail.asset.ringfenced].[vw_WorkOrder]
    WHERE
        [MaintenanceActivityType] IN
            (
                'C01', 'C14', 'C20', 'C02', 'C13', 'C03', 'C19', 'C23', 'C25', 'C26', 'C10', -- Mechanised Track Maintenance
                'C29', 'C37', 'C08', 'C47', 'C54', 'C43', 'C51', 'C53', 'C57', 'C50', 'C10', 'C30', 'C48', 'C54', 'C52', 'C06', 'C07', 'C44', 'C01', 'C57', -- General Track Maintenance
                'B50', 'B53', 'C67', 'B04', 'B05', 'B06', 'B55', 'B57', 'C67', -- Structures Maintenance
                'T28', 'T29', 'T40', 'T41', 'T58', 'T44', 'T45', 'T46', 'T47', 'T48', 'T54', 'T42', 'T43', -- Control Systems - Signalling and Wayside Maintenance
                'T10', 'T11', 'T32', -- Control Systems - Telecommunications Maintenance
                'C54', 'T32', -- Control Systems - Operational Systems Maintenance
                'T26', 'T27', 'T32', 'T24', 'T25' -- Traction Power Maintenance
            )
        AND [CompanyCode] = '5000'
        AND [MainUserStatusDesc] = 'Practically Completed'
        AND [ActualTotalCost] IS NOT NULL
        AND [ActualTotalCost] > 0
"""

# Define your server name
server_name = 'myanalytics.aurizon.com.au'

# Establish a connection using Windows Authentication
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + server_name + ';DATABASE=myANALYTICS_SP;Trusted_Connection=yes;')

# Execute the SQL query and load the result into a pandas DataFrame
df1 = pd.read_sql_query(sql_query, conn)

df1.to_pickle("../pkl/work_order_main_all.pkl")
# Display the DataFrame
df1
# Out:
# C:\Users\R893859\AppData\Local\Temp\ipykernel_1472\3057670730.py:42: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query(sql_query, conn)
#      WorkOrderNumber OrderType CompanyCode FunctionLocation CompletionDate  \
# 0       000080078613      MW04        5000         LU000040     2017-06-26
# 1       000080078614      MW04        5000         LU000034     2017-09-14
# 2       000080078615      MW04        5000         LU000033     2017-06-26
# 3       000080078616      MW04        5000         LU000035     2017-06-26
# 4       000080078656      MW04        5000          BW-03ML     2017-09-14
# ...              ...       ...         ...              ...            ...
# 9544    000058286508      NW03        5000          BW-28YR     2024-05-14
# 9545    000058286535      NW03        5000          MA-01FK     2024-05-14
# 9546    000058286530      NW03        5000          GA-01ML     2024-05-14
# 9547    000058286534      NW03        5000          MA-02FK     2024-05-14
# 9548    000058286533      NW03        5000          MA-03FK     2024-05-14
#
#      MaintenanceActivityType  MaintenanceActivityTypeDesc MainUserStatus  \
# 0                        C14  Ballast Excavator U/C Major           PCOM
# 1                        C14  Ballast Excavator U/C Major           PCOM
# 2                        C14  Ballast Excavator U/C Major           PCOM
# 3                        C14  Ballast Excavator U/C Major           PCOM
# 4                        C14  Ballast Excavator U/C Major           PCOM
# ...                      ...                          ...            ...
# 9544                     C50            Track Inspections           PCOM
# 9545                     C50            Track Inspections           PCOM
# 9546                     C50            Track Inspections           PCOM
# 9547                     C50            Track Inspections           PCOM
# 9548                     C50            Track Inspections           PCOM
#
#          MainUserStatusDesc  ActualTotalCost
# 0     Practically Completed          2291.71
# 1     Practically Completed          2036.69
# 2     Practically Completed          1316.68
# 3     Practically Completed          1316.69
# 4     Practically Completed         10992.73
# ...                     ...              ...
# 9544  Practically Completed           126.95
# 9545  Practically Completed           508.23
# 9546  Practically Completed          4553.29
# 9547  Practically Completed           126.95
# 9548  Practically Completed           126.95
#
# [9549 rows x 10 columns]

# %%
df2 = pd.read_pickle(r'C:\Users\R893859\Aurizon Operations Limited\Data, Reporting & Analytics - DS08 - NSAP2\Data\Huy\Flocs List\maint_flocs.pkl')
df2
# Out:
#          FuncLocID                                Maintenance Product
# 0      TO000226-01  Points (mechanical, electric, electro-hydrauli...
# 2      TO000226-02  Points (mechanical, electric, electro-hydrauli...
# 4      LX006284-01                     Level Crossing Warning Control
# 7      TO000310-01  Points (mechanical, electric, electro-hydrauli...
# 9      TO000147-01  Points (mechanical, electric, electro-hydrauli...
# ...            ...                                                ...
# 76328  ST008155-15                          Power Supplies (Electric)
# 76330  ST008155-19                          Power Supplies (Electric)
# 76332  ST008155-22                          Power Supplies (Electric)
# 76334  ST009535-06                          Power Supplies (Electric)
# 76336  ST009535-12                          Power Supplies (Electric)
#
# [60855 rows x 2 columns]

# %%
all_main_type_df = pd.DataFrame(df2['Maintenance Product'].unique(), columns=['Maintenance Product'])
all_main_type_df
# Out:
#                                   Maintenance Product
# 0   Points (mechanical, electric, electro-hydrauli...
# 1                      Level Crossing Warning Control
# 2   Train Control Systems (DTC signs, Local Panel,...
# 3                                            Isolator
# 4                     Housings (Apparatus Case & Hut)
# ..                                                ...
# 53                                  Track Resurfacing
# 54                           Track Geometry Recording
# 55                                            Fencing
# 56                   GPR / PVC Inspecting and Testing
# 57                                   Rail Lubrication
#
# [58 rows x 1 columns]

# %%
merged_df = pd.merge(df1, df2, how='left', left_on='FunctionLocation', right_on='FuncLocID')
merged_df
# Out:
#       WorkOrderNumber OrderType CompanyCode FunctionLocation CompletionDate  \
# 0        000080078613      MW04        5000         LU000040     2017-06-26
# 1        000080078614      MW04        5000         LU000034     2017-09-14
# 2        000080078615      MW04        5000         LU000033     2017-06-26
# 3        000080078616      MW04        5000         LU000035     2017-06-26
# 4        000080078656      MW04        5000          BW-03ML     2017-09-14
# ...               ...       ...         ...              ...            ...
# 36067    000058286533      NW03        5000          MA-03FK     2024-05-14
# 36068    000058286533      NW03        5000          MA-03FK     2024-05-14
# 36069    000058286533      NW03        5000          MA-03FK     2024-05-14
# 36070    000058286533      NW03        5000          MA-03FK     2024-05-14
# 36071    000058286533      NW03        5000          MA-03FK     2024-05-14
#
#       MaintenanceActivityType  MaintenanceActivityTypeDesc MainUserStatus  \
# 0                         C14  Ballast Excavator U/C Major           PCOM
# 1                         C14  Ballast Excavator U/C Major           PCOM
# 2                         C14  Ballast Excavator U/C Major           PCOM
# 3                         C14  Ballast Excavator U/C Major           PCOM
# 4                         C14  Ballast Excavator U/C Major           PCOM
# ...                       ...                          ...            ...
# 36067                     C50            Track Inspections           PCOM
# 36068                     C50            Track Inspections           PCOM
# 36069                     C50            Track Inspections           PCOM
# 36070                     C50            Track Inspections           PCOM
# 36071                     C50            Track Inspections           PCOM
#
#           MainUserStatusDesc  ActualTotalCost FuncLocID  \
# 0      Practically Completed          2291.71       NaN
# 1      Practically Completed          2036.69       NaN
# 2      Practically Completed          1316.68       NaN
# 3      Practically Completed          1316.69       NaN
# 4      Practically Completed         10992.73       NaN
# ...                      ...              ...       ...
# 36067  Practically Completed           126.95   MA-03FK
# 36068  Practically Completed           126.95   MA-03FK
# 36069  Practically Completed           126.95   MA-03FK
# 36070  Practically Completed           126.95   MA-03FK
# 36071  Practically Completed           126.95   MA-03FK
#
#                                      Maintenance Product
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36067                           Track Geometry Recording
# 36068                                  Track Inspections
# 36069                                Rail Flaw Detection
# 36070  General Earthworks Maintenance (incl. access r...
# 36071                   GPR / PVC Inspecting and Testing
#
# [36072 rows x 12 columns]

# %%
nan_count = merged_df['Maintenance Product'].isna().sum()
nan_count
# Out:
# 2834

# %%
# Convert CompletionDate column into datetime
merged_df['CompletionDate'] = pd.to_datetime(merged_df['CompletionDate'])
# merged_df['Asset Type'] = merged_df['Asset Type'].fillna('Unknown')

# Calculate all time average
grouped_all_time = merged_df.groupby('Maintenance Product').agg(
    Average_ActualTotalCost_All_Time=('ActualTotalCost', 'mean'),
    Sample_Size_All_Time=('Maintenance Product', 'size')
).reset_index()

grouped_all_time
# Out:
#                    Maintenance Product  Average_ActualTotalCost_All_Time  \
# 0                       Alternator Set                      82740.960000
# 1                 Ballast Undercutting                      22268.586900
# 2       Ballast Undercutting -Turnouts                      13030.126989
# 3     Copper Cable Route - Underground                       2140.168725
# 4    DC Power Supply - Battery Charger                       4655.836000
# ..                                 ...                               ...
# 38                        Transformers                      14076.057500
# 39      Transmission (Microwave Radio)                        219.770000
# 40  Transmission (Optic Fibre Systems)                        769.789927
# 41                    Turnout Grinding                      12358.809883
# 42                 Turnout Resurfacing                      13030.126989
#
#     Sample_Size_All_Time
# 0                      1
# 1                   3264
# 2                   1458
# 3                    102
# 4                     10
# ..                   ...
# 38                     4
# 39                     2
# 40                   137
# 41                  1545
# 42                  1458
#
# [43 rows x 3 columns]

# %%
# Calculate last year average
current_year = datetime.now().year
previous_year = current_year - 1

df_previous_year = merged_df[merged_df['CompletionDate'].dt.year == previous_year]

grouped_previous_year = df_previous_year.groupby('Maintenance Product').agg(
    Average_ActualTotalCost_Previous_Year=('ActualTotalCost', 'mean'),
    Sample_Size_Previous_Year=('Maintenance Product', 'size')
).reset_index()

grouped_previous_year
# Out:
#                                   Maintenance Product  \
# 0                                Ballast Undercutting
# 1                      Ballast Undercutting -Turnouts
# 2                   DC Power Supply - Battery Charger
# 3                    GPR / PVC Inspecting and Testing
# 4   General Earthworks Maintenance (incl. access r...
# ..                                                ...
# 16                           Track Geometry Recording
# 17                                  Track Inspections
# 18                                  Track Resurfacing
# 19                                   Turnout Grinding
# 20                                Turnout Resurfacing
#
#     Average_ActualTotalCost_Previous_Year  Sample_Size_Previous_Year
# 0                           209102.118065                        155
# 1                            55635.644395                        157
# 2                             4534.940000                          1
# 3                           262775.513663                        101
# 4                           238082.935351                        114
# ..                                    ...                        ...
# 16                          244076.497207                        111
# 17                          132384.689299                        271
# 18                          244076.497207                        111
# 19                           55635.644395                        157
# 20                           55635.644395                        157
#
# [21 rows x 3 columns]

# %%
# Calculate last 3 years average
last_3_years_start = current_year - 3

df_last_3_years = merged_df[(merged_df['CompletionDate'].dt.year >= last_3_years_start) & (merged_df['CompletionDate'].dt.year != current_year)]

grouped_last_3_years = df_last_3_years.groupby('Maintenance Product').agg(
    Average_Last_3_Years=('ActualTotalCost', 'mean'),
    Sample_Size_Last_3_Years=('Maintenance Product', 'size')
).reset_index()

grouped_last_3_years
# Out:
#                                   Maintenance Product  Average_Last_3_Years  \
# 0                                      Alternator Set          82740.960000
# 1                                Ballast Undercutting         151561.584684
# 2                      Ballast Undercutting -Turnouts          39028.878291
# 3                   DC Power Supply - Battery Charger           4655.836000
# 4                                 Fixed Radio Systems           3852.370000
# ..                                                ...                   ...
# 27  Train Control Systems (DTC signs, Local Panel,...          33201.240000
# 28                                       Transformers          18516.343333
# 29                 Transmission (Optic Fibre Systems)           1733.440000
# 30                                   Turnout Grinding          39028.878291
# 31                                Turnout Resurfacing          39028.878291
#
#     Sample_Size_Last_3_Years
# 0                          1
# 1                        348
# 2                        357
# 3                         10
# 4                          1
# ..                       ...
# 27                         1
# 28                         3
# 29                         1
# 30                       357
# 31                       357
#
# [32 rows x 3 columns]

# %%
# Calculate last 5 years average
last_5_years_start = current_year - 5

df_last_5_years = merged_df[(merged_df['CompletionDate'].dt.year >= last_5_years_start) & (merged_df['CompletionDate'].dt.year != current_year)]

grouped_last_5_years = df_last_5_years.groupby('Maintenance Product').agg(
    Average_Last_5_Years=('ActualTotalCost', 'mean'),
    Sample_Size_Last_5_Years=('Maintenance Product', 'size')
).reset_index()

grouped_last_5_years
# Out:
#                                   Maintenance Product  Average_Last_5_Years  \
# 0                                      Alternator Set          82740.960000
# 1                                Ballast Undercutting         137339.411979
# 2                      Ballast Undercutting -Turnouts          34854.352291
# 3                   DC Power Supply - Battery Charger           4655.836000
# 4                                             Fencing          36039.002500
# ..                                                ...                   ...
# 29  Train Control Systems (DTC signs, Local Panel,...          33201.240000
# 30                                       Transformers          18516.343333
# 31                 Transmission (Optic Fibre Systems)           1733.440000
# 32                                   Turnout Grinding          34854.352291
# 33                                Turnout Resurfacing          34854.352291
#
#     Sample_Size_Last_5_Years
# 0                          1
# 1                        389
# 2                        406
# 3                         10
# 4                          4
# ..                       ...
# 29                         1
# 30                         3
# 31                         1
# 32                       406
# 33                       406
#
# [34 rows x 3 columns]

# %%
result_df = pd.merge(grouped_all_time, grouped_previous_year, on='Maintenance Product', how='left')
result_df = pd.merge(result_df, grouped_last_3_years, on='Maintenance Product', how='left')
result_df = pd.merge(result_df, grouped_last_5_years, on='Maintenance Product', how='left')

result_df
# Out:
#                    Maintenance Product  Average_ActualTotalCost_All_Time  \
# 0                       Alternator Set                      82740.960000
# 1                 Ballast Undercutting                      22268.586900
# 2       Ballast Undercutting -Turnouts                      13030.126989
# 3     Copper Cable Route - Underground                       2140.168725
# 4    DC Power Supply - Battery Charger                       4655.836000
# ..                                 ...                               ...
# 38                        Transformers                      14076.057500
# 39      Transmission (Microwave Radio)                        219.770000
# 40  Transmission (Optic Fibre Systems)                        769.789927
# 41                    Turnout Grinding                      12358.809883
# 42                 Turnout Resurfacing                      13030.126989
#
#     Sample_Size_All_Time  Average_ActualTotalCost_Previous_Year  \
# 0                      1                                    NaN
# 1                   3264                          209102.118065
# 2                   1458                           55635.644395
# 3                    102                                    NaN
# 4                     10                            4534.940000
# ..                   ...                                    ...
# 38                     4                                    NaN
# 39                     2                                    NaN
# 40                   137                                    NaN
# 41                  1545                           55635.644395
# 42                  1458                           55635.644395
#
#     Sample_Size_Previous_Year  Average_Last_3_Years  Sample_Size_Last_3_Years  \
# 0                         NaN          82740.960000                       1.0
# 1                       155.0         151561.584684                     348.0
# 2                       157.0          39028.878291                     357.0
# 3                         NaN                   NaN                       NaN
# 4                         1.0           4655.836000                      10.0
# ..                        ...                   ...                       ...
# 38                        NaN          18516.343333                       3.0
# 39                        NaN                   NaN                       NaN
# 40                        NaN           1733.440000                       1.0
# 41                      157.0          39028.878291                     357.0
# 42                      157.0          39028.878291                     357.0
#
#     Average_Last_5_Years  Sample_Size_Last_5_Years
# 0           82740.960000                       1.0
# 1          137339.411979                     389.0
# 2           34854.352291                     406.0
# 3                    NaN                       NaN
# 4            4655.836000                      10.0
# ..                   ...                       ...
# 38          18516.343333                       3.0
# 39                   NaN                       NaN
# 40           1733.440000                       1.0
# 41          34854.352291                     406.0
# 42          34854.352291                     406.0
#
# [43 rows x 9 columns]

# %%
result_df = pd.merge(all_main_type_df, result_df, on='Maintenance Product', how='left')
result_df.to_pickle("../pkl/average_main_cost.pkl")

result_df
# Out:
#                                   Maintenance Product  \
# 0   Points (mechanical, electric, electro-hydrauli...
# 1                      Level Crossing Warning Control
# 2   Train Control Systems (DTC signs, Local Panel,...
# 3                                            Isolator
# 4                     Housings (Apparatus Case & Hut)
# ..                                                ...
# 53                                  Track Resurfacing
# 54                           Track Geometry Recording
# 55                                            Fencing
# 56                   GPR / PVC Inspecting and Testing
# 57                                   Rail Lubrication
#
#     Average_ActualTotalCost_All_Time  Sample_Size_All_Time  \
# 0                        4531.398329                 425.0
# 1                         638.559073                 399.0
# 2                       33201.240000                   1.0
# 3                       39436.809000                  30.0
# 4                         849.329205                  88.0
# ..                               ...                   ...
# 53                      19044.818991                3103.0
# 54                      19369.187372                3048.0
# 55                       6069.400486                 185.0
# 56                      23842.489331                2406.0
# 57                      25477.989370                2173.0
#
#     Average_ActualTotalCost_Previous_Year  Sample_Size_Previous_Year  \
# 0                            31150.930000                       12.0
# 1                             1071.244000                       10.0
# 2                                     NaN                        NaN
# 3                            49432.001538                       13.0
# 4                                     NaN                        NaN
# ..                                    ...                        ...
# 53                          244076.497207                      111.0
# 54                          244076.497207                      111.0
# 55                                    NaN                        NaN
# 56                          262775.513663                      101.0
# 57                          270525.278333                       96.0
#
#     Average_Last_3_Years  Sample_Size_Last_3_Years  Average_Last_5_Years  \
# 0           25131.625098                      51.0          22172.155085
# 1            1071.244000                      10.0           1071.244000
# 2           33201.240000                       1.0          33201.240000
# 3           38018.967273                      22.0          38018.967273
# 4            2776.480000                       3.0           3944.610000
# ..                   ...                       ...                   ...
# 53         182700.735652                     230.0         158930.123872
# 54         182700.735652                     230.0         158930.123872
# 55                   NaN                       NaN          36039.002500
# 56         189212.850639                     219.0         163497.482510
# 57         189941.885238                     210.0         163179.022967
#
#     Sample_Size_Last_5_Years
# 0                       59.0
# 1                       10.0
# 2                        1.0
# 3                       22.0
# 4                        5.0
# ..                       ...
# 53                     266.0
# 54                     266.0
# 55                       4.0
# 56                     255.0
# 57                     246.0
#
# [58 rows x 9 columns]
